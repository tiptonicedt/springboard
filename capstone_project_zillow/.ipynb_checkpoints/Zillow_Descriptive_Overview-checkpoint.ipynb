# %%
# %matplotlib inline
import pandas as pd

# %%
import numpy as np

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
homes1 = pd.DataFrame.from_csv('data/Zip_Zhvi_Summary_AllHomes.csv', index_col=None)
homes1.head()
# Out:
#          Date  RegionID  RegionName State     Metro    County      City  \
# 0  2017-05-31     61639       10025    NY  New York  New York  New York
# 1  2017-05-31     84654       60657    IL   Chicago      Cook   Chicago
# 2  2017-05-31     84616       60614    IL   Chicago      Cook   Chicago
# 3  2017-05-31     93144       79936    TX   El Paso   El Paso   El Paso
# 4  2017-05-31     84640       60640    IL   Chicago      Cook   Chicago
#
#    SizeRank     Zhvi       MoM       QoQ       YoY     5Year    10Year  \
# 0         0  1178700  0.030602  0.051097  0.108739  0.088801  0.049093
# 1         1   327700  0.005523  0.017070  0.031152  0.045528  0.002162
# 2         2   401900 -0.008633 -0.040124 -0.005198  0.045068  0.002856
# 3         3   114800  0.000872 -0.001739  0.025000  0.002280 -0.011594
# 4         4   205700 -0.004356  0.002437  0.050562  0.048406 -0.014355
#
#   PeakMonth PeakQuarter  PeakZHVI  PctFallFromPeak LastTimeAtCurrZHVI
# ...

# %%
homes2 = pd.DataFrame.from_csv('data/Zip_Zhvi_AllHomes.csv', index_col=None)
homes2.head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     84616       60614   Chicago    IL   Chicago       Cook         3
# 3     93144       79936   El Paso    TX   El Paso    El Paso         4
# 4     84640       60640   Chicago    IL   Chicago       Cook         5
#
#     1996-04   1996-05   1996-06   ...     2016-08  2016-09  2016-10  2016-11  \
# 0       NaN       NaN       NaN   ...     1128500  1133300  1132900  1147300
# 1  146700.0  146500.0  146300.0   ...      318600   318200   318100   318700
# 2  198000.0  195500.0  194200.0   ...      400700   401900   406000   414000
# 3   70800.0   71000.0   71000.0   ...      113700   113800   113800   114100
# 4  102300.0  101300.0  100700.0   ...      200000   198800   199200   200100
#
#      2016-12  2017-01  2017-02  2017-03  2017-04  2017-05
# ...

# %%
# Scatter plot of 10 year change vs ZHVI value
h = homes1
h.plot.scatter('10Year', 'Zhvi', s=None, c=None)

# %%
# Scatter plot of the total growth over the last 10 years vs size of the market
h = homes1
h.plot.scatter('10Year', 'SizeRank', s=None, c=None)

# %%
# TO DO - determining a best fit line for the scatterplots

# %%
# Transposing data

h = homes2
h = h.T
h.tail(10)
# Out:
#               0       1       2       3       4       5           6      \
# 2016-08     1128500  318600  400700  113700  200000  161200     1102600
# 2016-09     1133300  318200  401900  113800  198800  160500     1105300
# 2016-10     1132900  318100  406000  113800  199200  160600     1109200
# 2016-11     1147300  318700  414000  114100  200100  160600     1117800
# 2016-12  1.1498e+06  320200  417800  114500  201500  159100  1.1256e+06
# 2017-01     1132700  321000  417700  114900  203200  156900     1127700
# 2017-02     1121400  322200  418700  115000  205200  154600     1128600
# 2017-03     1123000  323800  414100  114700  206700  153400     1132000
# 2017-04     1143700  325900  405400  114700  206600  154100     1138300
# 2017-05     1178700  327700  401900  114800  205700  156200     1144000
#
#           7       8       9       ...     13095   13096   13097   13098  \
# 2016-08  297400  573700  160000   ...    218500  473200  168900  320500
# ...

# %%
# Attempting to transpose data after grouping by State
h = homes2
h = h.groupby(h.State)
h.T
h.plot.line(kind = 'line', s=None, c=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1dc393ed541b> in <module>()
#       2 h = homes2
#       3 h = h.groupby(h.State)
# ----> 4 h.T
#       5 h.plot.line(kind = 'line', s=None, c=None)
#
# /anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     546             return self[attr]
#     547         if hasattr(self.obj, attr):
# --> 548             return self._make_wrapper(attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
#
# /anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _make_wrapper(self, name)
#     560                    "using the 'apply' method".format(kind, name,
#     561                                                      type(self).__name__))
# --> 562             raise AttributeError(msg)
#     563
# ...

# %%
# Testing pivot tables
h = homes2
h = h.pivot(index='RegionName', columns='State', values=('2016-08'))
h.tail(300)
# Out:
# State             AK  AL  AR  AZ  CA  CO  CT  DC  DE  FL ...  RI  SC  TN  TX  \
# RegionName                                               ...
# 98109            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98112            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98115            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98116            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98117            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98118            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98119            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98121            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98122            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# 98125            NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ... NaN NaN NaN NaN
# ...

# %%
# Plot annual average growth for all US in the last 20 years

# %%
# Using melt to get all dates in a single column
h2 = homes2
h2 = pd.melt(h2, id_vars=["State", "RegionID", "RegionName", "City", "Metro", "CountyName", "SizeRank"], 
                  var_name="Date", value_name="Value")
h2.head()
# Out:
#   State  RegionID  RegionName      City     Metro CountyName  SizeRank  \
# 0    NY     61639       10025  New York  New York   New York         1
# 1    IL     84654       60657   Chicago   Chicago       Cook         2
# 2    IL     84616       60614   Chicago   Chicago       Cook         3
# 3    TX     93144       79936   El Paso   El Paso    El Paso         4
# 4    IL     84640       60640   Chicago   Chicago       Cook         5
#
#       Date     Value
# 0  1996-04       NaN
# 1  1996-04  146700.0
# 2  1996-04  198000.0
# 3  1996-04   70800.0
# 4  1996-04  102300.0

# %%
# Look how many rows after melt!
len(h2)
# Out:
# 3328670

# %%
# Charting overall growth of housing market over last 20 years - need to figure out why 'mean' is giving me issues
h2 = homes2
m = pd.melt(h2, id_vars=["State", "RegionID", "RegionName", "City", "Metro", "CountyName", "SizeRank"], 
                  var_name="Date", value_name="Value")
m = m.groupby('Date').mean()
m.plot('Date', 'Value')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-735f453f3661> in <module>()
#       4                   var_name="Date", value_name="Value")
#       5 m = m.groupby('Date').mean()
# ----> 6 m.plot('Date', 'Value')
#
# /anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2618                           fontsize=fontsize, colormap=colormap, table=table,
#    2619                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2620                           sort_columns=sort_columns, **kwds)
#    2621     __call__.__doc__ = plot_frame.__doc__
#    2622
#
# ...

# %%
# Show total growth by state for the last 20 years

# %%
# Need to try this without using melt

h2 = homes2
m = pd.melt(h2, id_vars=["State", "City", "Metro", "CountyName"], 
                  var_name="Date", value_name="Value")
m = m[(m.Date == "1996-04") | (m.Date == "2017-05")]
m = m.groupby(['State', 'Date']).mean()
m = m.unstack('Date')
m.head(10)
m["Growth"] = m.iloc[1] / m.iloc[0]
m = m.round(2)
m.head(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ff7c191c321c> in <module>()
#       6 m = m.unstack('Date')
#       7 m.head(10)
# ----> 8 m["Growth"] = m.iloc[1] / m.iloc[0]
#       9 m = m.round(2)
#      10 m.head(50)
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# ...

# %%
# plot annual growth by state for 5 slowest growing states for the last 20 years

# %%
# plot annual growth by state for 5 slowest growing states for the last 20 years

# %%
# plot annual growth by zip for 5 fastest growing zips for the last 20 years

# %%
# plot annual growth by zip for 5 slowest growing zips for the last 20 years
